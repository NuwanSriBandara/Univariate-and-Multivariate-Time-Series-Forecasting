# %% [markdown]
# <a href="https://colab.research.google.com/github/NuwanSriBandara/TeamCrypto_DataStorm3/blob/main/Semi_Final_Repo/Multivariate_LSTM_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.models import Model

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# from pandas_profiling import ProfileReport
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
# %matplotlib inline

# %% [markdown]
# ## Preprocessing the datasets

# %% [markdown]
# ### Training Dataset

# %%
# train_path = '../input/data-storm-30/train_data.csv'
train_path = 'filtered.csv'
# train_path = 'train_data.csv'
train_dataset = pd.read_csv(train_path)
train_dataset = train_dataset.drop_duplicates(keep = 'first')
train_dataset = train_dataset.filter(['ItemCode', 'CategoryCode', 'Week_num', 'WeeklySales','Unique_ID'])

# %%
print(train_dataset.columns)
print('No. of different categories: {}'.format(len(train_dataset['CategoryCode'].unique())))
print('No. of different items: {}'.format(len(train_dataset['ItemCode'].unique())))
# Out:
# Index(['ItemCode', 'CategoryCode', 'Week_num', 'WeeklySales', 'Unique_ID'], dtype='object')
# No. of different categories: 4
# No. of different items: 197

# %%
# # converting the dtype of the DateID
# train_dataset['DateID'] = pd.to_datetime(train_dataset['DateID'])
# train_dataset.sort_values(by = 'DateID', inplace=True)
# print(train_dataset.dtypes)

# %%
train_dataset.head()
# train_dataset
# Out:
#    ItemCode CategoryCode  Week_num  WeeklySales Unique_ID
# 0      3418   category_1         1         29.0    3418#1
# 1      3418   category_1         2         42.0    3418#2
# 2      3418   category_1         3         41.0    3418#3
# 3      3418   category_1         4         41.0    3418#4
# 4      3418   category_1         5         44.0    3418#5

# %%
flag = 0
for item in train_dataset['ItemCode'].unique():
    tmp_dataset = train_dataset.loc[train_dataset['ItemCode'] == item]
    if len(tmp_dataset['CategoryCode'].unique()) == 1:
        continue
    else:
        print('CategoryCode for an ItemCode is not unique')
        flag = 1
        break

# %%
def custom_ts_multi_data_prep(dataset, target, start, end, window, horizon):
    X = []
    y = []
    start = start + window
    if end is None:
        end = len(dataset) - horizon

    for i in range(start, end):
        indices = range(i-window, i)
        X.append(dataset[indices])

        indicey = range(i+1, i+1+horizon)
        y.append(target[indicey])
    return np.array(X), np.array(y)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
X_data = X_scaler.fit_transform(train_dataset[['CategoryCode', 'Week_num', 'DiscountType', 'DiscountValue','WeeklySales']])
Y_data = Y_scaler.fit_transform(train_dataset[['WeeklySales']])

# %%
hist_window = 5
horizon = 10
TRAIN_SPLIT = 120
x_train, y_train = custom_ts_multi_data_prep(X_data, Y_data, 0, TRAIN_SPLIT, hist_window, horizon)
x_vali, y_vali = custom_ts_multi_data_prep(X_data, Y_data, TRAIN_SPLIT, None, hist_window, horizon)

# %% [markdown]
# ### Validation Dataset

# %%
valid_path = 'validation_data.csv'
# valid_path = 'validation_data.csv'
validation_dataset = pd.read_csv(valid_path)
validation_dataset = validation_dataset.drop_duplicates(keep = 'first')
validation_dataset = validation_dataset.filter(['ItemCode', 'CategoryCode', 'Week_num', 'WeeklySales','Unique_ID'])

# %%
print(validation_dataset.columns)
print('No. of different categories: {}'.format(len(validation_dataset['CategoryCode'].unique())))
print('No. of different items: {}'.format(len(validation_dataset['ItemCode'].unique())))
# Out:
# Index(['ItemCode', 'CategoryCode', 'WeeklySales'], dtype='object')
# No. of different categories: 4
# No. of different items: 97

# %% [markdown]
# ### Test Dataset

# %%
test_path = 'test_data.csv'
test_dataset = pd.read_csv(test_path)
test_dataset = test_dataset.drop_duplicates(keep = 'first')

# %%
# print(test_dataset.columns)
# print('No. of different categories: {}'.format(len(test_dataset['CategoryCode'].unique())))
# print('No. of different items: {}'.format(len(test_dataset['ItemCode'].unique())))
# test_dataset.shape[0]

# %% [markdown]
# ## Defining the model

# %% [markdown]
# ### Windowing function

# %%
#if you are using convolutions, expand dim within the helper function
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis = -1)
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size +1, shift = 1, drop_remainder = True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size+1))
    dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1:]))
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %% [markdown]
# ### Plot Function

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %% [markdown]
# ### Forecast Function

# %%
#lets define a function for the forecasting part that would be used after training
def model_forecast(model, series, window_size):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size, shift= 1, drop_remainder = True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size))
    dataset = dataset.batch(32).prefetch(1)
    forecast = model.predict(dataset)
    
    return forecast

# %% [markdown]
# ### Writing to Test_data

# %%
# def edit_dataset(test_dataset,itemCode,predict_list):
#     for i in range(len(predict_list)):
#         week = "w" + str(i+1)
#         x =set(test_dataset[test_dataset['ItemCode']==itemCode].index.values)
#         y =set(test_dataset[test_dataset['Week']==week].index.values)
#         index = list(x.intersection(y))[0]
#         test_dataset.at[index, 'PredictedSales'] = predict_list[i]

# %% [markdown]
# ### Model

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=[None, 1]),
  tf.keras.layers.Conv1D(filters = 64, kernel_size=5, strides = 2, padding = 'causal', activation = 'relu'),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.Dense(32, activation="relu"),
  tf.keras.layers.Dense(16, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 50)
])



optimizer = tf.keras.optimizers.SGD(lr=1e-5, momentum=0.9)
loss = tf.keras.losses.Huber()

model.compile(loss= loss,optimizer=optimizer,metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ### Creating an empty dataframe

# %%
result_df = pd.DataFrame(columns = ('CategoryCode', 'ItemCode','Week', 'PredictedSales','MAPE'))

# %%
def write_to_df(df, category_code, item_code, predicted_sales,mape):
  for i in range(len(predicted_sales)):
    df = df.append({'CategoryCode':category_code,'ItemCode':item_code, 'Week': 'w'+str(i+1), 'MAPE':mape, 'PredictedSales':predicted_sales[i]}, ignore_index = True)
  return df

# %% [markdown]
# ### Picking an item

# %%
i = 1
for item_num in test_dataset['ItemCode'].unique():
  tmp_dataset_train = train_dataset.loc[train_dataset['ItemCode'] == item_num]
  weeks_train = np.array(tmp_dataset_train['Week_num'])
  sales_train = np.array(tmp_dataset_train['WeeklySales'])

  offset = len(weeks_train)

  # tmp_dataset_valid = validation_dataset.loc[validation_dataset['ItemCode'] == item_num]
  # weeks_valid = np.array(tmp_dataset_valid.pop('Week_num'))
  # weeks_valid = [offset + i for i in weeks_valid]
  # sales_valid = np.array(tmp_dataset_valid['WeeklySales'])

  weeks_test  = np.array([offset + i for i in range(4)])
  sales_test = np.zeros((4,))

  total_weeks = np.concatenate([weeks_train, weeks_test])
  total_sales = np.concatenate([sales_train, sales_test])

  window_size = 5
  batch_size = 10
  shuffle_buffer_size = 15
  train_set = windowed_dataset(sales_train, window_size, batch_size, shuffle_buffer_size)
  
  tf.keras.backend.clear_session()
  tf.random.set_seed(51)
  np.random.seed(51)

  print(f"Training the model for the item no. : {i}/{len(test_dataset['ItemCode'].unique())}")
  print("--------------------------------------------------------------------------------")
  history = model.fit(train_set,epochs=500)
  print("--------------------------------------------------------------------------------")
  mape = history.history["mean_absolute_percentage_error"][-1]

  lstm_forecast = model_forecast(model, total_sales[..., np.newaxis], window_size)
  lstm_forecast = lstm_forecast[offset - window_size:-1, -1, 0]

  # tf.keras.metrics.mean_absolute_percentage_error(sales_valid, lstm_forecast).numpy()
  category = tmp_dataset_train['CategoryCode'].unique()[0]
  result_df = write_to_df(result_df, category, item_num, lstm_forecast,mape)
  i += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 78/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5.3834 - mean_absolute_percentage_error: 24.4303
# Epoch 79/500
# 2/2 [==============================] - 0s 19ms/step - loss: 6.4587 - mean_absolute_percentage_error: 32.3403
# Epoch 80/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5.9939 - mean_absolute_percentage_error: 28.5513
# Epoch 81/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5303 - mean_absolute_percentage_error: 24.8253
# Epoch 82/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.6519 - mean_absolute_percentage_error: 25.5190
# Epoch 83/500
# 2/2 [==============================] - 0s 24ms/step - loss: 5.7691 - mean_absolute_percentage_error: 26.2682
# Epoch 84/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5.5136 - mean_absolute_percentage_error: 25.3426
# Epoch 85/500
# 2/2 [==============================] - 0s 19ms/step - loss: 5.3836 - mean_absolute_percentage_error: 24.9011
# Epoch 86/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5.4214 - mean_absolute_percentage_error: 26.4737
# Epoch 87/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.3882 - mean_absolute_percentage_error: 25.4253
# Epoch 88/500
# 2/2 [==============================] - 0s 19ms/step - loss: 5.3349 - mean_absolute_percentage_error: 24.4315
# Epoch 89/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.0380 - mean_absolute_percentage_error: 24.4136
# Epoch 90/500
# 2/2 [==============================] - 0s 22ms/step - loss: 5.0643 - mean_absolute_percentage_error: 24.1873
# Epoch 91/500
# 2/2 [==============================] - 0s 18ms/step - loss: 5.0781 - mean_absolute_percentage_error: 23.9707
# Epoch 92/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.9509 - mean_absolute_percentage_error: 23.9046
# Epoch 93/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.8794 - mean_absolute_percentage_error: 23.4088
# Epoch 94/500
# 2/2 [==============================] - 0s 17ms/step - loss: 5.1753 - mean_absolute_percentage_error: 24.2132
# Epoch 95/500
# 2/2 [==============================] - 0s 19ms/step - loss: 5.0393 - mean_absolute_percentage_error: 23.7891
# Epoch 96/500
# 2/2 [==============================] - 0s 19ms/step - loss: 5.1143 - mean_absolute_percentage_error: 23.8827
# Epoch 97/500
# 2/2 [==============================] - 0s 29ms/step - loss: 4.9610 - mean_absolute_percentage_error: 23.3290
# Epoch 98/500
# 2/2 [==============================] - 0s 23ms/step - loss: 5.0095 - mean_absolute_percentage_error: 23.3600
# Epoch 99/500
# 2/2 [==============================] - 0s 19ms/step - loss: 5.2848 - mean_absolute_percentage_error: 25.4187
# Epoch 100/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5
500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.6175 - mean_absolute_percentage_error: 21.4272
# Epoch 133/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.5451 - mean_absolute_percentage_error: 21.3149
# Epoch 134/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.4875 - mean_absolute_percentage_error: 20.9329
# Epoch 135/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.5223 - mean_absolute_percentage_error: 21.4936
# Epoch 136/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.8690 - mean_absolute_percentage_error: 22.0322
# Epoch 137/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.6355 - mean_absolute_percentage_error: 21.7144
# Epoch 138/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6061 - mean_absolute_percentage_error: 21.4158
# Epoch 139/500
# 2/2 [==============================] - 0s 19ms/step - loss: 5.0830 - mean_absolute_percentage_error: 22.2829
# Epoch 140/500
# 2/2 [==============================] - 0s 24ms/step - loss: 4.6034 - mean_absolute_percentage_error: 21.3138
# Epoch 141/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.7559 - mean_absolute_percentage_error: 21.7728
# Epoch 142/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.1185 - mean_absolute_percentage_error: 21.8721
# Epoch 143/500
# 2/2 [==============================] - 0s 25ms/step - loss: 4.9805 - mean_absolute_percentage_error: 23.0866
# Epoch 144/500
# 2/2 [==============================] - 0s 24ms/step - loss: 4.8317 - mean_absolute_percentage_error: 22.4002
# Epoch 145/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.9011 - mean_absolute_percentage_error: 21.3236
# Epoch 146/500
# 2/2 [==============================] - 0s 25ms/step - loss: 4.5385 - mean_absolute_percentage_error: 21.3183
# Epoch 147/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.5348 - mean_absolute_percentage_error: 20.5584
# Epoch 148/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.5656 - mean_absolute_percentage_error: 20.7332
# Epoch 149/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.7203 - mean_absolute_percentage_error: 21.4155
# Epoch 150/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.6384 - mean_absolute_percentage_error: 21.1473
# Epoch 151/500
# 2/2 [==============================] - 0s 26ms/step - loss: 4.5249 - mean_absolute_percentage_error: 21.0730
# Epoch 152/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.4091 - mean_absolute_percentage_error: 20.2289
# Epoch 153/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.4657 - mean_absolute_percentage_error: 20.4042
# Epoch 154/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.4305 - mean_absolute_percentage_error: 20.3813
# Epoch 155/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4406 - mean_absolute_percentage_error: 20.3407
# Epoch 156/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.5034 - mean_absolute_percentage_error: 21.2723
# Epoch 157/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.5920 - mean_absolute_percentage_error: 20.5037
# Epoch 158/500
# 2/2 [==============================] - 0s 27ms/step - loss: 4.6082 - mean_absolute_percentage_error: 21.6080
# Epoch 159/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2897 - mean_absolute_percentage_error: 19.5121
# Epoch 160/500
# 2/2 [==============================] - 0s 24ms/step - loss: 4.4368 - mean_absolute_percentage_error: 20.0537
# Epoch 161/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.4391 - mean_absolute_percentage_error: 19.6968
# Epoch 162/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3710 - mean_absolute_percentage_error: 19.7164
# Epoch 163/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.2786 - mean_absolute_percentage_error: 19.5813
# Epoch 164/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.3566 - mean_absolute_percentage_error: 19.8071
# Epoch 165/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.3088 - mean_absolute_percentage_error: 19.8706
# Epoch 166/500
# 2/2 [==============================] - 0s 33ms/step - loss: 4.2621 - mean_absolute_percentage_error: 19.1602
# Epoch 167/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.4791 - mean_absolute_percentage_error: 20.1757
# Epoch 168/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1696 - mean_absolute_percentage_error: 18.7367
# Epoch 169/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.2378 - mean_absolute_percentage_error: 18.9917
# Epoch 170/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2318 - mean_absolute_percentage_error: 19.2536
# Epoch 171/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.6322 - mean_absolute_percentage_error: 20.2595
# Epoch 172/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.5280 - mean_absolute_percentage_error: 20.9894
# Epoch 173/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2590 - mean_absolute_percentage_error: 19.5044
# Epoch 174/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.1972 - mean_absolute_percentage_error: 19.6071
# Epoch 175/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.2071 - mean_absolute_percentage_error: 19.2615
# Epoch 176/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1582 - mean_absolute_percentage_error: 19.2351
# Epoch 177/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3108 - mean_absolute_percentage_error: 19.3672
# Epoch 178/500
# 2/2 [==============================] - 0s 29ms/step - loss: 4.2932 - mean_absolute_percentage_error: 19.2950
# Epoch 179/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.5046 - mean_absolute_percentage_error: 20.1916
# Epoch 180/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1874 - mean_absolute_percentage_error: 18.9655
# Epoch 181/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3568 - mean_absolute_percentage_error: 20.1121
# Epoch 182/500
# 2/2 [==============================] - 0s 28ms/step - loss: 4.6147 - mean_absolute_percentage_error: 20.0730
# Epoch 183/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.4311 - mean_absolute_percentage_error: 20.4206
# Epoch 184/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.7434 - mean_absolute_percentage_error: 21.5325
# Epoch 185/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5.2661 - mean_absolute_percentage_error: 22.3856
# Epoch 186/500
# 2/2 [==============================] - 0s 29ms/step - loss: 4.5812 - mean_absolute_percentage_error: 20.9617
# Epoch 187/500
# 2/2 [==============================] - 0s 21ms/step - loss: 6.0232 - mean_absolute_percentage_error: 26.4800
# Epoch 188/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.9586 - mean_absolute_percentage_error: 21.9921
# Epoch 189/500
# 2/2 [==============================] - 0s 22ms/step - loss: 5.8324 - mean_absolute_percentage_error: 24.4599
# Epoch 190/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.5087 - mean_absolute_percentage_error: 21.2089
# Epoch 191/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.8790 - mean_absolute_percentage_error: 26.3767
# Epoch 192/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4907 - mean_absolute_percentage_error: 20.9592
# Epoch 193/500
# 2/2 [==============================] - 0s 22ms/step - loss: 5.1528 - mean_absolute_percentage_error: 22.3164
# Epoch 194/500
# 2/2 [==============================] - 0s 30ms/step - loss: 4.7445 - mean_absolute_percentage_error: 20.4737
# Epoch 195/500
# 2/2 [==============================] - 0s 21ms/step - loss: 5.0029 - mean_absolute_percentage_error: 22.5028
# Epoch 196/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.8284 - mean_absolute_percentage_error: 20.9406
# Epoch 197/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.9499 - mean_absolute_percentage_error: 21.0675
# Epoch 198/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.7305 - mean_absolute_percentage_error: 21.4643
# Epoch 199/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.3426 - mean_absolute_percentage_error: 20.3683
# Epoch 200/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.4348 - mean_absolute_percentage_error: 20.2489
# Epoch 201/500
# 2/2 [==============================] - 0s 25ms/step - loss: 4.3025 - mean_absolute_percentage_error: 19.2265
# Epoch 202/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.2935 - mean_absolute_percentage_error: 19.7023
# Epoch 203/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2341 - mean_absolute_percentage_error: 18.6024
# Epoch 204/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.1334 - mean_absolute_percentage_error: 18.4006
# Epoch 205/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.4292 - mean_absolute_percentage_error: 19.0561
# Epoch 206/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2817 - mean_absolute_percentage_error: 18.9689
# Epoch 207/500
# 2/2 [==============================] - 0s 29ms/step - loss: 4.2972 - mean_absolute_percentage_error: 19.3774
# Epoch 208/500
# 2/2 [==============================] - 0s 27ms/step - loss: 4.3967 - mean_absolute_percentage_error: 19.8397
# Epoch 209/500
# 2/2 [==============================] - 0s 27ms/step - loss: 4.2087 - mean_absolute_percentage_error: 19.0290
# Epoch 210/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1268 - mean_absolute_percentage_error: 18.8182
# Epoch 211/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.1600 - mean_absolute_percentage_error: 19.5821
# Epoch 212/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.2385 - mean_absolute_percentage_error: 18.8703
# Epoch 213/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3634 - mean_absolute_percentage_error: 19.5222
# Epoch 214/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2348 - mean_absolute_percentage_error: 18.8995
# Epoch 215/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.2447 - mean_absolute_percentage_error: 19.0995
# Epoch 216/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.2417 - mean_absolute_percentage_error: 19.0226
# Epoch 217/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.0464 - mean_absolute_percentage_error: 18.2651
# Epoch 218/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.2662 - mean_absolute_percentage_error: 18.8476
# Epoch 219/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1902 - mean_absolute_percentage_error: 19.3430
# Epoch 220/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.0471 - mean_absolute_percentage_error: 18.1048
# Epoch 221/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1009 - mean_absolute_percentage_error: 18.4319
# Epoch 222/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.1380 - mean_absolute_percentage_error: 18.4969
# Epoch 223/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.0415 - mean_absolute_percentage_error: 18.0780
# Epoch 224/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.0254 - mean_absolute_percentage_error: 18.0647
# Epoch 225/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.0563 - mean_absolute_percentage_error: 18.1572
# Epoch 226/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.0879 - mean_absolute_percentage_error: 18.1956
# Epoch 227/500
# 2/2 [==============================] - 0s 25ms/step - loss: 4.0235 - mean_absolute_percentage_error: 17.9234
# Epoch 228/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.1147 - mean_absolute_percentage_error: 18.4921
# Epoch 229/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.9949 - mean_absolute_percentage_error: 18.1496
# Epoch 230/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.9618 - mean_absolute_percentage_error: 18.0247
# Epoch 231/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9640 - mean_absolute_percentage_error: 17.8940
# Epoch 232/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.0432 - mean_absolute_percentage_error: 18.2343
# Epoch 233/500
# 2/2 [==============================] - 0s 26ms/step - loss: 4.2580 - mean_absolute_percentage_error: 18.7505
# Epoch 234/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3930 - mean_absolute_percentage_error: 20.3497
# Epoch 235/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.0662 - mean_absolute_percentage_error: 18.4698
# Epoch 236/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.2979 - mean_absolute_percentage_error: 18.7148
# Epoch 237/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.6148 - mean_absolute_percentage_error: 21.1807
# Epoch 238/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2585 - mean_absolute_percentage_error: 18.7647
# Epoch 239/500
# 2/2 [==============================] - 0s 26ms/step - loss: 4.5918 - mean_absolute_percentage_error: 19.5129
# Epoch 240/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.4728 - mean_absolute_percentage_error: 19.9878
# Epoch 241/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.2272 - mean_absolute_percentage_error: 18.8078
# Epoch 242/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.6783 - mean_absolute_percentage_error: 19.9895
# Epoch 243/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.0390 - mean_absolute_percentage_error: 18.5949
# Epoch 244/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.2578 - mean_absolute_percentage_error: 19.7370
# Epoch 245/500
# 2/2 [==============================] - 0s 29ms/step - loss: 4.7910 - mean_absolute_percentage_error: 20.1541
# Epoch 246/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3641 - mean_absolute_percentage_error: 18.9058
# Epoch 247/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.0846 - mean_absolute_percentage_error: 23.8856
# Epoch 248/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.7654 - mean_absolute_percentage_error: 20.6534
# Epoch 249/500
# 2/2 [==============================] - 0s 24ms/step - loss: 4.8621 - mean_absolute_percentage_error: 20.7719
# Epoch 250/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.3258 - mean_absolute_percentage_error: 20.3523
# Epoch 251/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.7531 - mean_absolute_percentage_error: 21.5513
# Epoch 252/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.4309 - mean_absolute_percentage_error: 19.6747
# Epoch 253/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.4784 - mean_absolute_percentage_error: 19.7132
# Epoch 254/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.5396 - mean_absolute_percentage_error: 20.0684
# Epoch 255/500
# 2/2 [==============================] - 0s 24ms/step - loss: 4.2713 - mean_absolute_percentage_error: 18.9322
# Epoch 256/500
# 2/2 [==============================] - 0s 29ms/step - loss: 4.1446 - mean_absolute_percentage_error: 18.7013
# Epoch 257/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.2750 - mean_absolute_percentage_error: 18.8127
# Epoch 258/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.0639 - mean_absolute_percentage_error: 18.0960
# Epoch 259/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.9539 - mean_absolute_percentage_error: 17.7696
# Epoch 260/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.1735 - mean_absolute_percentage_error: 19.1148
# Epoch 261/500
# 2/2 [==============================] - 0s 25ms/step - loss: 4.4074 - mean_absolute_percentage_error: 18.7134
# Epoch 262/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.9076 - mean_absolute_percentage_error: 17.7746
# Epoch 263/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.8565 - mean_absolute_percentage_error: 22.7823
# Epoch 264/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.1993 - mean_absolute_percentage_error: 19.1305
# Epoch 265/500
# 2/2 [==============================] - 0s 25ms/step - loss: 4.3780 - mean_absolute_percentage_error: 19.1417
# Epoch 266/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4183 - mean_absolute_percentage_error: 19.4833
# Epoch 267/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2050 - mean_absolute_percentage_error: 18.4202
# Epoch 268/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.2401 - mean_absolute_percentage_error: 18.5526
# Epoch 269/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.1605 - mean_absolute_percentage_error: 18.4350
# Epoch 270/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1202 - mean_absolute_percentage_error: 18.1434
# Epoch 271/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9894 - mean_absolute_percentage_error: 17.3580
# Epoch 272/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9741 - mean_absolute_percentage_error: 17.3840
# Epoch 273/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.8946 - mean_absolute_percentage_error: 17.1593
# Epoch 274/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8565 - mean_absolute_percentage_error: 16.9739
# Epoch 275/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.8672 - mean_absolute_percentage_error: 17.1832
# Epoch 276/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9493 - mean_absolute_percentage_error: 17.7710
# Epoch 277/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.0998 - mean_absolute_percentage_error: 17.8033
# Epoch 278/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9367 - mean_absolute_percentage_error: 17.7706
# Epoch 279/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.8516 - mean_absolute_percentage_error: 16.9552
# Epoch 280/500
# 2/2 [==============================] - 0s 28ms/step - loss: 4.1270 - mean_absolute_percentage_error: 17.9586
# Epoch 281/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9787 - mean_absolute_percentage_error: 17.9110
# Epoch 282/500
# 2/2 [==============================] - 0s 27ms/step - loss: 4.1510 - mean_absolute_percentage_error: 18.0791
# Epoch 283/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.9195 - mean_absolute_percentage_error: 17.8185
# Epoch 284/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8681 - mean_absolute_percentage_error: 17.4773
# Epoch 285/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.2378 - mean_absolute_percentage_error: 18.1783
# Epoch 286/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.8812 - mean_absolute_percentage_error: 17.3540
# Epoch 287/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8970 - mean_absolute_percentage_error: 17.3917
# Epoch 288/500
# 2/2 [==============================] - 0s 20ms/step - loss: 5.0160 - mean_absolute_percentage_error: 20.5775
# Epoch 289/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.0327 - mean_absolute_percentage_error: 17.6313
# Epoch 290/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.6828 - mean_absolute_percentage_error: 21.7118
# Epoch 291/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.3919 - mean_absolute_percentage_error: 18.8403
# Epoch 292/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.1398 - mean_absolute_percentage_error: 17.9715
# Epoch 293/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.5885 - mean_absolute_percentage_error: 21.7386
# Epoch 294/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.9056 - mean_absolute_percentage_error: 17.8919
# Epoch 295/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.6441 - mean_absolute_percentage_error: 19.3909
# Epoch 296/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.9992 - mean_absolute_percentage_error: 18.3878
# Epoch 297/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.9993 - mean_absolute_percentage_error: 17.9257
# Epoch 298/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.8074 - mean_absolute_percentage_error: 20.1545
# Epoch 299/500
# 2/2 [==============================] - 0s 34ms/step - loss: 4.3612 - mean_absolute_percentage_error: 19.1917
# Epoch 300/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.7234 - mean_absolute_percentage_error: 20.9784
# Epoch 301/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.0947 - mean_absolute_percentage_error: 18.0948
# Epoch 302/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6139 - mean_absolute_percentage_error: 19.5514
# Epoch 303/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.5405 - mean_absolute_percentage_error: 20.5687
# Epoch 304/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3720 - mean_absolute_percentage_error: 19.1028
# Epoch 305/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4149 - mean_absolute_percentage_error: 18.9979
# Epoch 306/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.9074 - mean_absolute_percentage_error: 17.7881
# Epoch 307/500
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9032 - mean_absolute_percentage_error: 17.5802
# Epoch 308/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.9561 - mean_absolute_percentage_error: 17.6257
# Epoch 309/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8123 - mean_absolute_percentage_error: 17.1950
# Epoch 310/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.7632 - mean_absolute_percentage_error: 16.6467
# Epoch 311/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7929 - mean_absolute_percentage_error: 16.9398
# Epoch 312/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.8487 - mean_absolute_percentage_error: 16.7907
# Epoch 313/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7738 - mean_absolute_percentage_error: 16.9362
# Epoch 314/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7506 - mean_absolute_percentage_error: 16.6853
# Epoch 315/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7537 - mean_absolute_percentage_error: 16.6830
# Epoch 316/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7931 - mean_absolute_percentage_error: 16.6983
# Epoch 317/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.9534 - mean_absolute_percentage_error: 17.1171
# Epoch 318/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.8149 - mean_absolute_percentage_error: 16.9753
# Epoch 319/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.7900 - mean_absolute_percentage_error: 16.5293
# Epoch 320/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.8922 - mean_absolute_percentage_error: 17.1871
# Epoch 321/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.7480 - mean_absolute_percentage_error: 16.6667
# Epoch 322/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9036 - mean_absolute_percentage_error: 16.9888
# Epoch 323/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.0306 - mean_absolute_percentage_error: 17.6479
# Epoch 324/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.9555 - mean_absolute_percentage_error: 16.9669
# Epoch 325/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.7539 - mean_absolute_percentage_error: 16.3245
# Epoch 326/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.8332 - mean_absolute_percentage_error: 17.1159
# Epoch 327/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.7529 - mean_absolute_percentage_error: 16.2672
# Epoch 328/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8032 - mean_absolute_percentage_error: 16.1539
# Epoch 329/500
# 2/2 [==============================] - 0s 16ms/step - loss: 3.9989 - mean_absolute_percentage_error: 17.1949
# Epoch 330/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.9820 - mean_absolute_percentage_error: 16.7040
# Epoch 331/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8315 - mean_absolute_percentage_error: 16.9172
# Epoch 332/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.8608 - mean_absolute_percentage_error: 17.0222
# Epoch 333/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.8076 - mean_absolute_percentage_error: 16.6678
# Epoch 334/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.1827 - mean_absolute_percentage_error: 18.2971
# Epoch 335/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.0894 - mean_absolute_percentage_error: 17.6034
# Epoch 336/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.9386 - mean_absolute_percentage_error: 17.0108
# Epoch 337/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.9448 - mean_absolute_percentage_error: 17.7002
# Epoch 338/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.5237 - mean_absolute_percentage_error: 18.6318
# Epoch 339/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3772 - mean_absolute_percentage_error: 18.6958
# Epoch 340/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.5493 - mean_absolute_percentage_error: 20.4294
# Epoch 341/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4402 - mean_absolute_percentage_error: 18.5048
# Epoch 342/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8920 - mean_absolute_percentage_error: 17.1894
# Epoch 343/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9221 - mean_absolute_percentage_error: 17.6773
# Epoch 344/500
# 2/2 [==============================] - 0s 27ms/step - loss: 4.1094 - mean_absolute_percentage_error: 17.6696
# Epoch 345/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.0269 - mean_absolute_percentage_error: 18.1834
# Epoch 346/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.7827 - mean_absolute_percentage_error: 16.6261
# Epoch 347/500
# 2/2 [==============================] - 0s 27ms/step - loss: 3.9485 - mean_absolute_percentage_error: 16.7779
# Epoch 348/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.9454 - mean_absolute_percentage_error: 17.7554
# Epoch 349/500
# 2/2 [==============================] - 0s 26ms/step - loss: 4.0263 - mean_absolute_percentage_error: 17.3130
# Epoch 350/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.7653 - mean_absolute_percentage_error: 17.0249
# Epoch 351/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.7629 - mean_absolute_percentage_error: 16.8064
# Epoch 352/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.8950 - mean_absolute_percentage_error: 17.0255
# Epoch 353/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.9744 - mean_absolute_percentage_error: 18.0371
# Epoch 354/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.7621 - mean_absolute_percentage_error: 16.2734
# Epoch 355/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.7177 - mean_absolute_percentage_error: 16.3029
# Epoch 356/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.6799 - mean_absolute_percentage_error: 15.8522
# Epoch 357/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7198 - mean_absolute_percentage_error: 16.2842
# Epoch 358/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.6973 - mean_absolute_percentage_error: 16.2235
# Epoch 359/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.6684 - mean_absolute_percentage_error: 15.9786
# Epoch 360/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.6713 - mean_absolute_percentage_error: 15.7957
# Epoch 361/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.6261 - mean_absolute_percentage_error: 15.7168
# Epoch 362/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.8224 - mean_absolute_percentage_error: 16.1199
# Epoch 363/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.6996 - mean_absolute_percentage_error: 16.5329
# Epoch 364/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.6098 - mean_absolute_percentage_error: 15.8489
# Epoch 365/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7052 - mean_absolute_percentage_error: 16.0969
# Epoch 366/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.6459 - mean_absolute_percentage_error: 15.8016
# Epoch 367/500
# 2/2 [==============================] - 0s 29ms/step - loss: 3.8150 - mean_absolute_percentage_error: 16.5570
# Epoch 368/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9163 - mean_absolute_percentage_error: 17.1745
# Epoch 369/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8430 - mean_absolute_percentage_error: 16.5771
# Epoch 370/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7159 - mean_absolute_percentage_error: 16.2917
# Epoch 371/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.7328 - mean_absolute_percentage_error: 16.1729
# Epoch 372/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9655 - mean_absolute_percentage_error: 17.0093
# Epoch 373/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8929 - mean_absolute_percentage_error: 16.8055
# Epoch 374/500
# 2/2 [==============================] - 0s 16ms/step - loss: 4.0212 - mean_absolute_percentage_error: 17.4097
# Epoch 375/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8776 - mean_absolute_percentage_error: 17.3020
# Epoch 376/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8275 - mean_absolute_percentage_error: 16.8069
# Epoch 377/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8495 - mean_absolute_percentage_error: 16.3226
# Epoch 378/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8880 - mean_absolute_percentage_error: 16.3258
# Epoch 379/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.6639 - mean_absolute_percentage_error: 15.6941
# Epoch 380/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.7799 - mean_absolute_percentage_error: 16.6824
# Epoch 381/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.9428 - mean_absolute_percentage_error: 16.6475
# Epoch 382/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.8662 - mean_absolute_percentage_error: 16.4359
# Epoch 383/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.7726 - mean_absolute_percentage_error: 16.3453
# Epoch 384/500
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7920 - mean_absolute_percentage_error: 16.1667
# Epoch 385/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7209 - mean_absolute_percentage_error: 16.1333
# Epoch 386/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.6947 - mean_absolute_percentage_error: 15.8692
# Epoch 387/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.6691 - mean_absolute_percentage_error: 15.8248
# Epoch 388/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.8792 - mean_absolute_percentage_error: 17.3986
# Epoch 389/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.6740 - mean_absolute_percentage_error: 15.8107
# Epoch 390/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.6203 - mean_absolute_percentage_error: 15.6736
# Epoch 391/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.6309 - mean_absolute_percentage_error: 15.5499
# Epoch 392/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.5729 - mean_absolute_percentage_error: 15.2807
# Epoch 393/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.5710 - mean_absolute_percentage_error: 15.4963
# Epoch 394/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.5742 - mean_absolute_percentage_error: 15.5103
# Epoch 395/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.5915 - mean_absolute_percentage_error: 15.7336
# Epoch 396/500
# 2/2 [==============================] - 0s 29ms/step - loss: 3.7631 - mean_absolute_percentage_error: 16.2704
# Epoch 397/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7335 - mean_absolute_percentage_error: 16.3981
# Epoch 398/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7470 - mean_absolute_percentage_error: 16.2370
# Epoch 399/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.9431 - mean_absolute_percentage_error: 17.5749
# Epoch 400/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.0676 - mean_absolute_percentage_error: 17.0566
# Epoch 401/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.0060 - mean_absolute_percentage_error: 17.5742
# Epoch 402/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.1829 - mean_absolute_percentage_error: 18.8514
# Epoch 403/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.2630 - mean_absolute_percentage_error: 18.1622
# Epoch 404/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.0725 - mean_absolute_percentage_error: 18.6077
# Epoch 405/500
# 2/2 [==============================] - 0s 27ms/step - loss: 3.8875 - mean_absolute_percentage_error: 16.7319
# Epoch 406/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.5011 - mean_absolute_percentage_error: 18.7998
# Epoch 407/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.1179 - mean_absolute_percentage_error: 17.6982
# Epoch 408/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.2128 - mean_absolute_percentage_error: 18.3151
# Epoch 409/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.4593 - mean_absolute_percentage_error: 18.7997
# Epoch 410/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9107 - mean_absolute_percentage_error: 17.1956
# Epoch 411/500
# 2/2 [==============================] - 0s 14ms/step - loss: 4.1970 - mean_absolute_percentage_error: 18.8117
# Epoch 412/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4687 - mean_absolute_percentage_error: 18.6137
# Epoch 413/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.7370 - mean_absolute_percentage_error: 16.2126
# Epoch 414/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.6622 - mean_absolute_percentage_error: 21.0015
# Epoch 415/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.8799 - mean_absolute_percentage_error: 16.6889
# Epoch 416/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.1135 - mean_absolute_percentage_error: 17.2095
# Epoch 417/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.4418 - mean_absolute_percentage_error: 20.2130
# Epoch 418/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.1806 - mean_absolute_percentage_error: 18.0749
# Epoch 419/500
# 2/2 [==============================] - 0s 23ms/step - loss: 4.3330 - mean_absolute_percentage_error: 17.6997
# Epoch 420/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.8644 - mean_absolute_percentage_error: 17.5299
# Epoch 421/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7081 - mean_absolute_percentage_error: 16.0657
# Epoch 422/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.6826 - mean_absolute_percentage_error: 15.7484
# Epoch 423/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.6834 - mean_absolute_percentage_error: 16.0058
# Epoch 424/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7579 - mean_absolute_percentage_error: 16.1323
# Epoch 425/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.7702 - mean_absolute_percentage_error: 17.0054
# Epoch 426/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.0330 - mean_absolute_percentage_error: 16.7763
# Epoch 427/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.7716 - mean_absolute_percentage_error: 16.3567
# Epoch 428/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.9596 - mean_absolute_percentage_error: 17.4167
# Epoch 429/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.4207 - mean_absolute_percentage_error: 18.6300
# Epoch 430/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.8058 - mean_absolute_percentage_error: 16.5657
# Epoch 431/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.9445 - mean_absolute_percentage_error: 17.1853
# Epoch 432/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.3845 - mean_absolute_percentage_error: 18.4627
# Epoch 433/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7894 - mean_absolute_percentage_error: 16.9485
# Epoch 434/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.2950 - mean_absolute_percentage_error: 19.5110
# Epoch 435/500
# 2/2 [==============================] - 0s 26ms/step - loss: 4.3222 - mean_absolute_percentage_error: 17.5126
# Epoch 436/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.9618 - mean_absolute_percentage_error: 16.7508
# Epoch 437/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.5755 - mean_absolute_percentage_error: 20.6492
# Epoch 438/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.1179 - mean_absolute_percentage_error: 17.7967
# Epoch 439/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.4046 - mean_absolute_percentage_error: 18.4385
# Epoch 440/500
# 2/2 [==============================] - 0s 21ms/step - loss: 4.3698 - mean_absolute_percentage_error: 19.8235
# Epoch 441/500
# 2/2 [==============================] - 0s 20ms/step - loss: 4.4329 - mean_absolute_percentage_error: 19.1038
# Epoch 442/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.3616 - mean_absolute_percentage_error: 18.3134
# Epoch 443/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.9529 - mean_absolute_percentage_error: 17.5496
# Epoch 444/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.7489 - mean_absolute_percentage_error: 16.5371
# Epoch 445/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.8963 - mean_absolute_percentage_error: 16.6517
# Epoch 446/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.9864 - mean_absolute_percentage_error: 17.3869
# Epoch 447/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8674 - mean_absolute_percentage_error: 16.7264
# Epoch 448/500
# 2/2 [==============================] - 0s 34ms/step - loss: 3.7066 - mean_absolute_percentage_error: 16.2349
# Epoch 449/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.8845 - mean_absolute_percentage_error: 17.3430
# Epoch 450/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8944 - mean_absolute_percentage_error: 16.7384
# Epoch 451/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.7134 - mean_absolute_percentage_error: 16.2412
# Epoch 452/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.7496 - mean_absolute_percentage_error: 16.5339
# Epoch 453/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.0575 - mean_absolute_percentage_error: 17.3119
# Epoch 454/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.7615 - mean_absolute_percentage_error: 16.7703
# Epoch 455/500
# 2/2 [==============================] - 0s 22ms/step - loss: 4.1869 - mean_absolute_percentage_error: 19.3509
# Epoch 456/500
# 2/2 [==============================] - 0s 30ms/step - loss: 3.8472 - mean_absolute_percentage_error: 16.2140
# Epoch 457/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.8107 - mean_absolute_percentage_error: 17.2505
# Epoch 458/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.9264 - mean_absolute_percentage_error: 17.1320
# Epoch 459/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.8087 - mean_absolute_percentage_error: 16.6900
# Epoch 460/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.0628 - mean_absolute_percentage_error: 17.9878
# Epoch 461/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.8402 - mean_absolute_percentage_error: 16.8730
# Epoch 462/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.6348 - mean_absolute_percentage_error: 15.9582
# Epoch 463/500
# 2/2 [==============================] - 0s 17ms/step - loss: 4.1606 - mean_absolute_percentage_error: 18.1633
# Epoch 464/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.2753 - mean_absolute_percentage_error: 17.9246
# Epoch 465/500
# 2/2 [==============================] - 0s 19ms/step - loss: 4.0526 - mean_absolute_percentage_error: 16.9896
# Epoch 466/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.9752 - mean_absolute_percentage_error: 17.8124
# Epoch 467/500
# 2/2 [==============================] - 0s 18ms/step - loss: 4.1874 - mean_absolute_percentage_error: 17.9153
# ...
# Epoch 442/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.3542 - mean_absolute_percentage_error: 17.5574
# Epoch 443/500
# 2/2 [==============================] - 0s 31ms/step - loss: 3.3568 - mean_absolute_percentage_error: 17.9115
# Epoch 444/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3448 - mean_absolute_percentage_error: 17.3081
# Epoch 445/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.3659 - mean_absolute_percentage_error: 17.8012
# Epoch 446/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.3522 - mean_absolute_percentage_error: 17.4635
# Epoch 447/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3395 - mean_absolute_percentage_error: 16.9300
# Epoch 448/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3330 - mean_absolute_percentage_error: 16.7809
# Epoch 449/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.3326 - mean_absolute_percentage_error: 16.7776
# Epoch 450/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.3351 - mean_absolute_percentage_error: 16.6816
# Epoch 451/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.3311 - mean_absolute_percentage_error: 16.5505
# Epoch 452/500
# 2/2 [==============================] - 0s 28ms/step - loss: 3.3317 - mean_absolute_percentage_error: 16.4585
# Epoch 453/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.3339 - mean_absolute_percentage_error: 16.9497
# Epoch 454/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.3362 - mean_absolute_percentage_error: 16.8028
# Epoch 455/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3401 - mean_absolute_percentage_error: 16.7818
# Epoch 456/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.3387 - mean_absolute_percentage_error: 17.2863
# Epoch 457/500
# 2/2 [==============================] - 0s 26ms/step - loss: 3.3309 - mean_absolute_percentage_error: 16.7582
# Epoch 458/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.3436 - mean_absolute_percentage_error: 17.4067
# Epoch 459/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.3496 - mean_absolute_percentage_error: 17.6632
# Epoch 460/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3548 - mean_absolute_percentage_error: 16.6728
# Epoch 461/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.3532 - mean_absolute_percentage_error: 17.5323
# Epoch 462/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.3519 - mean_absolute_percentage_error: 17.1511
# Epoch 463/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3662 - mean_absolute_percentage_error: 18.2682
# Epoch 464/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.3958 - mean_absolute_percentage_error: 18.2694
# Epoch 465/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4051 - mean_absolute_percentage_error: 18.7188
# Epoch 466/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4096 - mean_absolute_percentage_error: 17.6006
# Epoch 467/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4049 - mean_absolute_percentage_error: 18.7456
# Epoch 468/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3938 - mean_absolute_percentage_error: 18.3412
# Epoch 469/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3824 - mean_absolute_percentage_error: 17.6218
# Epoch 470/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4374 - mean_absolute_percentage_error: 20.1383
# Epoch 471/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.3721 - mean_absolute_percentage_error: 17.6469
# Epoch 472/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4486 - mean_absolute_percentage_error: 18.5658
# Epoch 473/500
# 2/2 [==============================] - 0s 23ms/step - loss: 3.5500 - mean_absolute_percentage_error: 19.6706
# Epoch 474/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4098 - mean_absolute_percentage_error: 17.8967
# Epoch 475/500
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4764 - mean_absolute_percentage_error: 17.9021
# Epoch 476/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4531 - mean_absolute_percentage_error: 19.8668
# Epoch 477/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.3777 - mean_absolute_percentage_error: 17.8705
# Epoch 478/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4504 - mean_absolute_percentage_error: 18.7780
# Epoch 479/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4662 - mean_absolute_percentage_error: 18.2865
# Epoch 480/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4335 - mean_absolute_percentage_error: 17.8909
# Epoch 481/500
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4117 - mean_absolute_percentage_error: 18.1837
# Epoch 482/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4457 - mean_absolute_percentage_error: 17.9455
# Epoch 483/500
# 2/2 [==============================] - 0s 21ms/step - loss: 3.6042 - mean_absolute_percentage_error: 22.0420
# Epoch 484/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.3354 - mean_absolute_percentage_error: 16.8847
# Epoch 485/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.5355 - mean_absolute_percentage_error: 19.5066
# Epoch 486/500
# 2/2 [==============================] - 0s 25ms/step - loss: 3.5140 - mean_absolute_percentage_error: 18.5570
# Epoch 487/500
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4061 - mean_absolute_percentage_error: 18.1030
# Epoch 488/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.4456 - mean_absolute_percentage_error: 17.6490
# Epoch 489/500
# 2/2 [==============================] - 0s 17ms/step - loss: 3.3955 - mean_absolute_percentage_error: 19.7147
# Epoch 490/500
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4047 - mean_absolute_percentage_error: 19.8450
# Epoch 491/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4733 - mean_absolute_percentage_error: 18.5399
# Epoch 492/500
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4597 - mean_absolute_percentage_error: 17.6655
# Epoch 493/500
# 2/2 [==============================] - 0s 18ms/step - loss: 3.3953 - mean_absolute_percentage_error: 17.3942
# Epoch 494/500
# 2/2 [==============================] - 0s 20ms/step - loss: 3.